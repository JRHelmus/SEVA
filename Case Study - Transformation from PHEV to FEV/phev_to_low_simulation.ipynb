# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import seaborn
import pandas
import pickle
import numpy
import datetime
import math
import os
import scipy

# %%
import sys
import datetime

import simulation
import data_handler
import environment
import agent 

import imp
imp.reload(agent)
imp.reload(simulation)
imp.reload(data_handler)
imp.reload(environment)
# Out:
# <module 'environment' from '/home/ignavermeulen/modeling_charging_behavior/environment.py'>

# %%
# %time sim_phev_to_low = simulation.Simulation("data/input_parameters/parameters.json", \
    overwrite_parameters = {'agent_initialization': 'load_and_use', \
    'filepath_agent_database': 'data/agent_database/all_non_changing_agents/', 'number_of_agents': 10000, \
    'transform_parameters': { \
            "prob_no_transform": 0.0, \
            "prob_to_low_fev": 1.0, \
            "prob_to_high_fev": 0.0 \
          }, \
    'agent_creation_method': 'random', \
    'agent_IDs': ['ED984ED74DE3FB028AB32398F54B39E11428B5EBEB93D1C95A0F880721840C73', \
                  '51D1F1D5E18DA0E658443C436684A50D7FF2F553D3B651AD37C839082A1264BE', \
                  '3169D0D7B3168EC70C595FE9F6B03E9051495AFB420440CCEED363BBE795D9DB', \
                  '7B79B6458ECC90EE58B30BA903257AB719EE109AC9B2D49A6535E0C418F7417A', \
                  '032CD719366F497813DB007EBE7E728C7D009C40AA39681AE09C8FE71CEC5F88'], \
    'skip_high_fev_agents': True, \
    'skip_low_fev_agents': True})
# Out:
# INFO: Initialization
# 	INFO: Loading sessions took 1.51 seconds
# 	INFO: Detailed preprocessing took 2.13 seconds
# 	INFO: Initializing (load_and_use) 10000 random agents
# WARNING: Skipping low fev agent.
# 		INFO: 10 of 10000 agents are initialized
# 			INFO: 11 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.22 seconds
# 		INFO: 20 of 10000 agents are initialized
# 			INFO: 21 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.70 seconds
# 		INFO: 30 of 10000 agents are initialized
# 			INFO: 31 of 2287 users are processed
# 		INFO: Initialized 10 agents in 16.30 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 40 of 10000 agents are initialized
# 			INFO: 44 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.62 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 50 of 10000 agents are initialized
# 			INFO: 57 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.80 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 60 of 10000 agents are initialized
# 			INFO: 70 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.64 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 70 of 10000 agents are initialized
# 			INFO: 82 of 2287 users are processed
# 		INFO: Initialized 10 agents in 17.12 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 80 of 10000 agents are initialized
# 			INFO: 95 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.40 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 90 of 10000 agents are initialized
# 			INFO: 107 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.60 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 100 of 10000 agents are initialized
# 			INFO: 119 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.96 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 110 of 10000 agents are initialized
# 			INFO: 131 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.60 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 120 of 10000 agents are initialized
# 			INFO: 146 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.87 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 130 of 10000 agents are initialized
# 			INFO: 158 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.30 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 140 of 10000 agents are initialized
# 			INFO: 171 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.25 seconds
# 		INFO: 150 of 10000 agents are initialized
# 			INFO: 181 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.80 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 160 of 10000 agents are initialized
# 			INFO: 193 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.51 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 170 of 10000 agents are initialized
# 			INFO: 204 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.28 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 180 of 10000 agents are initialized
# 			INFO: 217 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.96 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 190 of 10000 agents are initialized
# 			INFO: 229 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.40 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 200 of 10000 agents are initialized
# 			INFO: 241 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.51 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 210 of 10000 agents are initialized
# 			INFO: 257 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.40 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 220 of 10000 agents are initialized
# 			INFO: 268 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.14 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 230 of 10000 agents are initialized
# 			INFO: 280 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.48 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 240 of 10000 agents are initialized
# 			INFO: 294 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.91 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 250 of 10000 agents are initialized
# 			INFO: 307 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.59 seconds
# 		INFO: 260 of 10000 agents are initialized
# 			INFO: 317 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.00 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 270 of 10000 agents are initialized
# 			INFO: 331 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.02 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 280 of 10000 agents are initialized
# 			INFO: 343 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.34 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 290 of 10000 agents are initialized
# 			INFO: 358 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.04 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 300 of 10000 agents are initialized
# 			INFO: 371 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.04 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 310 of 10000 agents are initialized
# 			INFO: 385 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.85 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 320 of 10000 agents are initialized
# 			INFO: 396 of 2287 users are processed
# 		INFO: Initialized 10 agents in 6.51 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 330 of 10000 agents are initialized
# 			INFO: 410 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.15 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 340 of 10000 agents are initialized
# 			INFO: 424 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.25 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 350 of 10000 agents are initialized
# 			INFO: 437 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.56 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 360 of 10000 agents are initialized
# 			INFO: 451 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.40 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 370 of 10000 agents are initialized
# 			INFO: 464 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.89 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 380 of 10000 agents are initialized
# 			INFO: 479 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.52 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 390 of 10000 agents are initialized
# 			INFO: 490 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.30 seconds
# 		INFO: 400 of 10000 agents are initialized
# 			INFO: 500 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.50 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 410 of 10000 agents are initialized
# 			INFO: 513 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.06 seconds
# 		INFO: 420 of 10000 agents are initialized
# 			INFO: 523 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.56 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 430 of 10000 agents are initialized
# 			INFO: 538 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.97 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 440 of 10000 agents are initialized
# 			INFO: 550 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.54 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 450 of 10000 agents are initialized
# 			INFO: 564 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.14 seconds
# WARNING: Skipping high fev agent.
# 		INFO: 460 of 10000 agents are initialized
# 			INFO: 575 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.82 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 470 of 10000 agents are initialized
# 			INFO: 587 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.88 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 480 of 10000 agents are initialized
# 			INFO: 599 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.37 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 490 of 10000 agents are initialized
# 			INFO: 611 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.82 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 500 of 10000 agents are initialized
# 			INFO: 624 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.18 seconds
# 		INFO: 510 of 10000 agents are initialized
# 			INFO: 634 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.58 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 520 of 10000 agents are initialized
# 			INFO: 646 of 2287 users are processed
# 		INFO: Initialized 10 agents in 16.80 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 530 of 10000 agents are initialized
# 			INFO: 659 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.36 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 540 of 10000 agents are initialized
# 			INFO: 672 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.16 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 550 of 10000 agents are initialized
# 			INFO: 683 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.70 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 560 of 10000 agents are initialized
# 			INFO: 694 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.95 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 570 of 10000 agents are initialized
# 			INFO: 707 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.85 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 580 of 10000 agents are initialized
# 			INFO: 720 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.76 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 590 of 10000 agents are initialized
# 			INFO: 735 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.24 seconds
# WARNING: Skipping high fev agent.
# 		INFO: 600 of 10000 agents are initialized
# 			INFO: 746 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.45 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 610 of 10000 agents are initialized
# 			INFO: 759 of 2287 users are processed
# 		INFO: Initialized 10 agents in 17.91 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 620 of 10000 agents are initialized
# 			INFO: 771 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.79 seconds
# WARNING: Skipping high fev agent.
# 		INFO: 630 of 10000 agents are initialized
# 			INFO: 782 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.87 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 640 of 10000 agents are initialized
# 			INFO: 796 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.85 seconds
# 		INFO: 650 of 10000 agents are initialized
# 			INFO: 806 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.96 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 660 of 10000 agents are initialized
# 			INFO: 818 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.77 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 670 of 10000 agents are initialized
# 			INFO: 832 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.56 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 680 of 10000 agents are initialized
# 			INFO: 845 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.87 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 690 of 10000 agents are initialized
# 			INFO: 863 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.66 seconds
# WARNING: Skipping high fev agent.
# 		INFO: 700 of 10000 agents are initialized
# 			INFO: 874 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.01 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 710 of 10000 agents are initialized
# 			INFO: 890 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.16 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 720 of 10000 agents are initialized
# 			INFO: 904 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.17 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 730 of 10000 agents are initialized
# 			INFO: 916 of 2287 users are processed
# 		INFO: Initialized 10 agents in 7.71 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 740 of 10000 agents are initialized
# 			INFO: 928 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.38 seconds
# 		INFO: 750 of 10000 agents are initialized
# 			INFO: 938 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.19 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 760 of 10000 agents are initialized
# 			INFO: 950 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.42 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 770 of 10000 agents are initialized
# 			INFO: 964 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.33 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 780 of 10000 agents are initialized
# 			INFO: 976 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.57 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 790 of 10000 agents are initialized
# 			INFO: 987 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.45 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 800 of 10000 agents are initialized
# 			INFO: 999 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.95 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 810 of 10000 agents are initialized
# 			INFO: 1014 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.81 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 820 of 10000 agents are initialized
# 			INFO: 1028 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.09 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 830 of 10000 agents are initialized
# 			INFO: 1043 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.35 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 840 of 10000 agents are initialized
# 			INFO: 1057 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.29 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 850 of 10000 agents are initialized
# 			INFO: 1069 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.41 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 860 of 10000 agents are initialized
# 			INFO: 1083 of 2287 users are processed
# 		INFO: Initialized 10 agents in 19.08 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 870 of 10000 agents are initialized
# 			INFO: 1094 of 2287 users are processed
# 		INFO: Initialized 10 agents in 17.76 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 880 of 10000 agents are initialized
# 			INFO: 1109 of 2287 users are processed
# 		INFO: Initialized 10 agents in 16.22 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 890 of 10000 agents are initialized
# 			INFO: 1121 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.60 seconds
# 		INFO: 900 of 10000 agents are initialized
# 			INFO: 1131 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.11 seconds
# WARNING: Skipping high fev agent.
# 		INFO: 910 of 10000 agents are initialized
# 			INFO: 1142 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.15 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 920 of 10000 agents are initialized
# 			INFO: 1153 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.54 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 930 of 10000 agents are initialized
# 			INFO: 1165 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.80 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 940 of 10000 agents are initialized
# 			INFO: 1177 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.48 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 950 of 10000 agents are initialized
# 			INFO: 1190 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.38 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 960 of 10000 agents are initialized
# 			INFO: 1204 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.12 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 970 of 10000 agents are initialized
# 			INFO: 1219 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.06 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 980 of 10000 agents are initialized
# 			INFO: 1232 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.96 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 990 of 10000 agents are initialized
# 			INFO: 1248 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.42 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1000 of 10000 agents are initialized
# 			INFO: 1259 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.16 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1010 of 10000 agents are initialized
# 			INFO: 1271 of 2287 users are processed
# 		INFO: Initialized 10 agents in 6.54 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1020 of 10000 agents are initialized
# 			INFO: 1283 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.88 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1030 of 10000 agents are initialized
# 			INFO: 1295 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.54 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1040 of 10000 agents are initialized
# 			INFO: 1311 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.76 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1050 of 10000 agents are initialized
# 			INFO: 1324 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.88 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1060 of 10000 agents are initialized
# 			INFO: 1336 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.95 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1070 of 10000 agents are initialized
# 			INFO: 1350 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.49 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1080 of 10000 agents are initialized
# 			INFO: 1362 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.65 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1090 of 10000 agents are initialized
# 			INFO: 1380 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.18 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1100 of 10000 agents are initialized
# 			INFO: 1393 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.27 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1110 of 10000 agents are initialized
# 			INFO: 1408 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.14 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1120 of 10000 agents are initialized
# 			INFO: 1419 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.86 seconds
# WARNING: Skipping high fev agent.
# 		INFO: 1130 of 10000 agents are initialized
# 			INFO: 1430 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.61 seconds
# 		INFO: 1140 of 10000 agents are initialized
# 			INFO: 1440 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.80 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1150 of 10000 agents are initialized
# 			INFO: 1454 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.58 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1160 of 10000 agents are initialized
# 			INFO: 1466 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.76 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1170 of 10000 agents are initialized
# 			INFO: 1478 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.45 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1180 of 10000 agents are initialized
# 			INFO: 1489 of 2287 users are processed
# 		INFO: Initialized 10 agents in 18.11 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1190 of 10000 agents are initialized
# 			INFO: 1505 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.00 seconds
# 		INFO: 1200 of 10000 agents are initialized
# 			INFO: 1515 of 2287 users are processed
# 		INFO: Initialized 10 agents in 7.71 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1210 of 10000 agents are initialized
# 			INFO: 1528 of 2287 users are processed
# 		INFO: Initialized 10 agents in 18.58 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1220 of 10000 agents are initialized
# 			INFO: 1540 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.27 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1230 of 10000 agents are initialized
# 			INFO: 1553 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.79 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1240 of 10000 agents are initialized
# 			INFO: 1565 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.93 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1250 of 10000 agents are initialized
# 			INFO: 1576 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.40 seconds
# 		INFO: 1260 of 10000 agents are initialized
# 			INFO: 1586 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.65 seconds
# 		INFO: 1270 of 10000 agents are initialized
# 			INFO: 1596 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.01 seconds
# WARNING: Skipping high fev agent.
# 		INFO: 1280 of 10000 agents are initialized
# 			INFO: 1607 of 2287 users are processed
# 		INFO: Initialized 10 agents in 17.25 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1290 of 10000 agents are initialized
# 			INFO: 1620 of 2287 users are processed
# 		INFO: Initialized 10 agents in 18.20 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1300 of 10000 agents are initialized
# 			INFO: 1632 of 2287 users are processed
# 		INFO: Initialized 10 agents in 20.86 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1310 of 10000 agents are initialized
# 			INFO: 1648 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.24 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1320 of 10000 agents are initialized
# 			INFO: 1661 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.59 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1330 of 10000 agents are initialized
# 			INFO: 1676 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.44 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1340 of 10000 agents are initialized
# 			INFO: 1688 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.33 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1350 of 10000 agents are initialized
# 			INFO: 1701 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.09 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1360 of 10000 agents are initialized
# 			INFO: 1713 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.73 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1370 of 10000 agents are initialized
# 			INFO: 1728 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.55 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1380 of 10000 agents are initialized
# 			INFO: 1741 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.94 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1390 of 10000 agents are initialized
# 			INFO: 1756 of 2287 users are processed
# 		INFO: Initialized 10 agents in 16.89 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1400 of 10000 agents are initialized
# 			INFO: 1768 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.37 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1410 of 10000 agents are initialized
# 			INFO: 1782 of 2287 users are processed
# 		INFO: Initialized 10 agents in 16.60 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1420 of 10000 agents are initialized
# 			INFO: 1795 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.29 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1430 of 10000 agents are initialized
# 			INFO: 1806 of 2287 users are processed
# 		INFO: Initialized 10 agents in 7.09 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1440 of 10000 agents are initialized
# 			INFO: 1819 of 2287 users are processed
# 		INFO: Initialized 10 agents in 16.39 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1450 of 10000 agents are initialized
# 			INFO: 1831 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.39 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1460 of 10000 agents are initialized
# 			INFO: 1842 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.64 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1470 of 10000 agents are initialized
# 			INFO: 1857 of 2287 users are processed
# 		INFO: Initialized 10 agents in 17.38 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1480 of 10000 agents are initialized
# 			INFO: 1871 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.28 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1490 of 10000 agents are initialized
# 			INFO: 1887 of 2287 users are processed
# 		INFO: Initialized 10 agents in 17.43 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1500 of 10000 agents are initialized
# 			INFO: 1899 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.51 seconds
# 		INFO: 1510 of 10000 agents are initialized
# 			INFO: 1909 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.66 seconds
# 		INFO: 1520 of 10000 agents are initialized
# 			INFO: 1919 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.56 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1530 of 10000 agents are initialized
# 			INFO: 1931 of 2287 users are processed
# 		INFO: Initialized 10 agents in 13.14 seconds
# WARNING: Skipping high fev agent.
# 		INFO: 1540 of 10000 agents are initialized
# 			INFO: 1942 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.77 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1550 of 10000 agents are initialized
# 			INFO: 1954 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.33 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1560 of 10000 agents are initialized
# 			INFO: 1965 of 2287 users are processed
# 		INFO: Initialized 10 agents in 19.19 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1570 of 10000 agents are initialized
# 			INFO: 1978 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.76 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1580 of 10000 agents are initialized
# 			INFO: 1989 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.47 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1590 of 10000 agents are initialized
# 			INFO: 2004 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.97 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1600 of 10000 agents are initialized
# 			INFO: 2016 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.75 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1610 of 10000 agents are initialized
# 			INFO: 2030 of 2287 users are processed
# 		INFO: Initialized 10 agents in 11.50 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1620 of 10000 agents are initialized
# 			INFO: 2043 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.32 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1630 of 10000 agents are initialized
# 			INFO: 2057 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.13 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1640 of 10000 agents are initialized
# 			INFO: 2070 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.76 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1650 of 10000 agents are initialized
# 			INFO: 2088 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.03 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1660 of 10000 agents are initialized
# 			INFO: 2103 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.61 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1670 of 10000 agents are initialized
# 			INFO: 2119 of 2287 users are processed
# 		INFO: Initialized 10 agents in 19.22 seconds
# WARNING: Skipping low fev agent.
# 		INFO: 1680 of 10000 agents are initialized
# 			INFO: 2130 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.35 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1690 of 10000 agents are initialized
# 			INFO: 2143 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.64 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1700 of 10000 agents are initialized
# 			INFO: 2155 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.25 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1710 of 10000 agents are initialized
# 			INFO: 2167 of 2287 users are processed
# 		INFO: Initialized 10 agents in 12.64 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1720 of 10000 agents are initialized
# 			INFO: 2181 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.89 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1730 of 10000 agents are initialized
# 			INFO: 2200 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.02 seconds
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# 		INFO: 1740 of 10000 agents are initialized
# 			INFO: 2212 of 2287 users are processed
# 		INFO: Initialized 10 agents in 8.27 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1750 of 10000 agents are initialized
# 			INFO: 2231 of 2287 users are processed
# 		INFO: Initialized 10 agents in 15.47 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1760 of 10000 agents are initialized
# 			INFO: 2243 of 2287 users are processed
# 		INFO: Initialized 10 agents in 9.27 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping high fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1770 of 10000 agents are initialized
# 			INFO: 2257 of 2287 users are processed
# 		INFO: Initialized 10 agents in 10.41 seconds
# 		INFO: 1780 of 10000 agents are initialized
# 			INFO: 2267 of 2287 users are processed
# 		INFO: Initialized 10 agents in 14.33 seconds
# WARNING: Skipping low fev agent.
# WARNING: Skipping low fev agent.
# 		INFO: 1790 of 10000 agents are initialized
# 			INFO: 2279 of 2287 users are processed
# 		INFO: Initialized 10 agents in 16.16 seconds
# WARNING: Skipping low fev agent.
# 		WARNING: Requested amount of agents not possible. Continuing with simulation using 1797 agents.
# 	INFO: Initialization took 37.56 minutes
# CPU times: user 36min 28s, sys: 1min 4s, total: 37min 33s
# Wall time: 37min 34s

# %%
filepath_agent_database = 'data/agent_database/phev_to_low_transformed_agents/'
for agent in sim_phev_to_low.agents.values():
    my_agent_data = agent._get_agent_data()
    with open(filepath_agent_database + agent.ID + '.pkl', 'wb') as agent_file:
        pickle.dump(my_agent_data, agent_file)

# %%
# %time sim_phev_to_low.repeat_simulation(repeat = 1, method = 'relMAE', measures = [])
# Out:
# INFO: Simulation repeat 1 of 1
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# 	INFO: Progress of simulation: 0.1WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# WARNING: Came out of for-loop in check_next_disconnection_time with value 71 but still not correct connection duration.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-73fa4157c28d> in <module>()
# ----> 1 get_ipython().magic("time sim_phev_to_low.repeat_simulation(repeat = 1, method = 'relMAE', measures = [])")
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2161         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2162         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2163         return self.run_line_magic(magic_name, magic_arg_s)
#    2164
#    2165     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2082                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2083             with self.builtin_trap:
# -> 2084                 result = fn(*args,**kwargs)
#    2085             return result
#    2086
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1171         if mode=='eval':
#    1172             st = clock2()
# -> 1173             out = eval(code, glob, local_ns)
#    1174             end = clock2()
#    1175         else:
#
# <timed eval> in <module>()
#
# /home/ignavermeulen/modeling_charging_behavior/simulation.py in repeat_simulation(self, repeat, measures, method, display_progress)
#     591             begin = time.process_time()
#     592
# --> 593             self._simulate(display_progress = display_progress)
#     594
#     595             if 'time_per_simulation' in measures:
#
# /home/ignavermeulen/modeling_charging_behavior/simulation.py in _simulate(self, display_progress)
#     726         while not self._stop(display_progress):
#     727             time_next_activity, succesfully_executed_activity = \
# --> 728                 self._execute_activity(active_agent)
#     729             if succesfully_executed_activity:
#     730                 self.sensors['nr_activities_executed_per_agent'][-1][active_agent.ID] += 1
#
# /home/ignavermeulen/modeling_charging_behavior/simulation.py in _execute_activity(self, agent)
#     814
#     815             ''' Next activity of agent is connecting '''
# --> 816             agent.get_next_connection_time_and_place()
#     817             succesfully_executed_activity = True
#     818         else:
#
# /home/ignavermeulen/modeling_charging_behavior/agent.py in get_next_connection_time_and_place(self)
#    1270         index = self.data_handler.index_dist(time)
#    1271         disconnection_duration = \
# -> 1272             self.data_handler.sample(self.disconnection_duration_dists[index])
#    1273         self.time_next_activity = time + disconnection_duration
#    1274         self._check_next_connection_time(time)
#
# /home/ignavermeulen/modeling_charging_behavior/data_handler.py in sample(self, p)
#    1191         times = [datetime.timedelta(0) + (bin_nr + random.random()) *
#    1192              datetime.timedelta(minutes = self.bin_size_dist)
# -> 1193              for bin_nr in range(len(p))]
#    1194         try:
#    1195             p = p / numpy.sum(p)
#
# /home/ignavermeulen/modeling_charging_behavior/data_handler.py in <listcomp>(.0)
#    1191         times = [datetime.timedelta(0) + (bin_nr + random.random()) *
#    1192              datetime.timedelta(minutes = self.bin_size_dist)
# -> 1193              for bin_nr in range(len(p))]
#    1194         try:
#    1195             p = p / numpy.sum(p)
#
# KeyboardInterrupt:

# %%
a= list(sim_phev_to_high.agents.values())[0]
len(a.all_simulated_sessions[0])
# Out:
# 152

# %%
all_sessions = pandas.DataFrame()
for a in sim_phev_to_high.agents.values():
    all_sessions = all_sessions.append(a.all_simulated_sessions[0])

# %%
print(len(all_sessions))
# Out:
# 216904

# %%
path_to_file = 'data/sessions/ChargeSessions_simulated_phev_to_low.pkl'
with open(path_to_file, 'wb') as data_file:
    pickle.dump(all_sessions, data_file)

# %%
((all_sessions))
# Out:
#          end_connection postal_code location_key    start_connection  \
# 1   2016-01-10 10:03:00      3015GE         4982 2016-01-09 17:42:00
# 2   2016-01-13 09:56:00      3015GE         4982 2016-01-12 18:45:00
# 3   2016-01-15 07:16:00      3015GE         4982 2016-01-14 12:40:00
# 4   2016-01-17 07:12:00      3015GE         4982 2016-01-16 09:38:00
# 5   2016-01-19 10:13:00      3015GE         4982 2016-01-18 19:44:00
# 6   2016-01-22 10:12:00      3015GE         4982 2016-01-21 18:53:00
# 7   2016-01-25 11:53:00      3015GE         4982 2016-01-24 17:30:00
# 8   2016-01-28 08:07:00      3015GE         4982 2016-01-27 20:32:00
# 9   2016-01-31 08:51:00      3015GE         4982 2016-01-30 17:33:00
# 10  2016-02-02 06:55:00      3015GE         4982 2016-02-01 15:46:00
# 11  2016-02-03 20:37:00      3015GE         4982 2016-02-03 08:44:00
# 12  2016-02-06 07:22:00      3015GE         4982 2016-02-05 15:22:00
# 13  2016-02-08 07:53:00      3015GE         4982 2016-02-07 15:38:00
# 14  2016-02-10 06:58:00      3015GE         4982 2016-02-09 19:09:00
# 15  2016-02-11 20:38:00      3015GE         4982 2016-02-11 08:56:00
# 16  2016-02-14 07:43:00      3015GE         4982 2016-02-13 15:25:00
# 17  2016-02-16 07:24:00      3015GE         4982 2016-02-15 11:07:00
# 18  2016-02-20 07:52:00      3015GE         4982 2016-02-19 19:04:00
# 19  2016-02-22 07:42:00      3015GE         4982 2016-02-21 14:43:00
# 20  2016-02-28 16:13:00      3015GE         4982 2016-02-26 19:57:00
# 21  2016-03-03 07:56:00      3015GE         4982 2016-03-01 11:27:00
# 22  2016-03-05 06:26:00      3015GE         4982 2016-03-04 14:38:00
# 23  2016-03-07 12:23:00      3015GE         4982 2016-03-06 13:22:00
# 24  2016-03-10 14:08:00      3015GE         4982 2016-03-09 22:09:00
# 25  2016-03-12 07:52:00      3015GE         4982 2016-03-11 20:26:00
# 26  2016-03-14 08:15:00      3015GE         4982 2016-03-13 18:56:00
# 27  2016-03-17 08:56:00      3015GE         4982 2016-03-16 17:39:00
# 28  2016-03-19 07:09:00      3015GE         4982 2016-03-18 15:53:00
# 29  2016-03-20 10:02:00      3015GE         4982 2016-03-20 09:48:00
# 30  2016-03-22 11:45:00      3015GE         4982 2016-03-21 17:27:00
# ..                  ...         ...          ...                 ...
# 94   DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 95   DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 96   DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 97   DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 98   DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 99   DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 100  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 101  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 102  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 103  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 104  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 105  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 106  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 107  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 108  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 109  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 110  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
# 111  DBADC3CE5A02EB1C197D0644EAFE8C44C29B7733BDBF10...           Rotterdam
#
#      kWh                      address  longitude         subdistrict  \
# 1     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 2     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 3     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 4     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 5     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 6     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 7     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 8     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 9     -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 10    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 11    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 12    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 13    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 14    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 15    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 16    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 17    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 18    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 19    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 20    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 21    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 22    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 23    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 24    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 25    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 26    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 27    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 28    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 29    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# 30    -1          Nieuwe Binnenweg104   4.467434            Dijkzigt
# ..   ...                          ...        ...                 ...
# 82    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 83    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 84    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 85    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 86    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 87    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 88    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 89    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 90    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 91    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 92    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 93    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 94    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 95    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 96    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 97    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 98    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 99    -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 100   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 101   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 102   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 103   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 104   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 105   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 106   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 107   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 108   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 109   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 110   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
# 111   -1  Juliana van Stolberglaan 54   4.478213  Hillegersberg zuid
#
#                      district  connection_time_hours       city   latitude  \
# 1           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 2           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 3           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 4           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 5           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 6           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 7           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 8           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 9           Rotterdam Centrum                     -1  Rotterdam  51.915628
# 10          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 11          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 12          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 13          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 14          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 15          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 16          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 17          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 18          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 19          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 20          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 21          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 22          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 23          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 24          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 25          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 26          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 27          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 28          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 29          Rotterdam Centrum                     -1  Rotterdam  51.915628
# 30          Rotterdam Centrum                     -1  Rotterdam  51.915628
# ..                        ...                    ...        ...        ...
# 82   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 83   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 84   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 85   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 86   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 87   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 88   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 89   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 90   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 91   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 92   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 93   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 94   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 95   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 96   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 97   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 98   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 99   Hillegersberg Schiebroek                     -1  Rotterdam  51.944576
# 17    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 18    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 19    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 20    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 21    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 22    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 23    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 24    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 25    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 26    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 27    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 28    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 29    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 30    -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# ..   ...                  ...        ...         ...                ...
# 123   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 124   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 125   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 126   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 127   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 128   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 129   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 130   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 131   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 132   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 133   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 134   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 135   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 136   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 137   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 138   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 139   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 140   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 141   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 142   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 143   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 144   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 145   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 146   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 147   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 148   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 149   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 150   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 151   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
# 152   -1  Nieuwe Binnenweg104   4.467434    Dijkzigt  Rotterdam Centrum
#
#      connection_time_hours       city   latitude provider  amount_of_sockets  \
# 1                       -1  Rotterdam  51.915628    EVBOX                  2
# 2                       -1  Rotterdam  51.915628    EVBOX                  2
# 3                       -1  Rotterdam  51.915628    EVBOX                  2
# 4                       -1  Rotterdam  51.915628    EVBOX                  2
# 5                       -1  Rotterdam  51.915628    EVBOX                  2
# 6                       -1  Rotterdam  51.915628    EVBOX                  2
# 7                       -1  Rotterdam  51.915628    EVBOX                  2
# 8                       -1  Rotterdam  51.915628    EVBOX                  2
# 9                       -1  Rotterdam  51.915628    EVBOX                  2
# 10                      -1  Rotterdam  51.915628    EVBOX                  2
# 11                      -1  Rotterdam  51.915628    EVBOX                  2
# 12                      -1  Rotterdam  51.915628    EVBOX                  2
# 13                      -1  Rotterdam  51.915628    EVBOX                  2
# 14                      -1  Rotterdam  51.915628    EVBOX                  2
# 15                      -1  Rotterdam  51.915628    EVBOX                  2
# 16                      -1  Rotterdam  51.915628    EVBOX                  2
# 17                      -1  Rotterdam  51.915628    EVBOX                  2
# 18                      -1  Rotterdam  51.915628    EVBOX                  2
# 19                      -1  Rotterdam  51.915628    EVBOX                  2
# 20                      -1  Rotterdam  51.915628    EVBOX                  2
# 21                      -1  Rotterdam  51.915628    EVBOX                  2
# 22                      -1  Rotterdam  51.915628    EVBOX                  2
# 23                      -1  Rotterdam  51.915628    EVBOX                  2
# 24                      -1  Rotterdam  51.915628    EVBOX                  2
# 25                      -1  Rotterdam  51.915628    EVBOX                  2
# 26                      -1  Rotterdam  51.915628    EVBOX                  2
# 27                      -1  Rotterdam  51.915628    EVBOX                  2
# 28                      -1  Rotterdam  51.915628    EVBOX                  2
# 29                      -1  Rotterdam  51.915628    EVBOX                  2
# 30                      -1  Rotterdam  51.915628    EVBOX                  2
# ..                     ...        ...        ...      ...                ...
# 123                     -1  Rotterdam  51.915628    EVBOX                  2
# 124                     -1  Rotterdam  51.915628    EVBOX                  2
# 125                     -1  Rotterdam  51.915628    EVBOX                  2
# 126                     -1  Rotterdam  51.915628    EVBOX                  2
# 127                     -1  Rotterdam  51.915628    EVBOX                  2
# 128                     -1  Rotterdam  51.915628    EVBOX                  2
# 142 2014-01-01 11:46:34
# 143 2014-01-01 11:46:34
# 144 2014-01-01 11:46:34
# 145 2014-01-01 11:46:34
# 146 2014-01-01 11:46:34
# 147 2014-01-01 11:46:34
# 148 2014-01-01 11:46:34
# 149 2014-01-01 11:46:34
# 150 2014-01-01 11:46:34
# 151 2014-01-01 11:46:34
# 152 2014-01-01 11:46:34
#
# [152 rows x 17 columns]

# %%
def save_agent(directory, agent_data, agent_ID):
    with open(directory + agent_ID + '.pkl', 'wb') as agent_file:
        pickle.dump(agent_data, agent_file)
        
def load_agent(directory, agent_ID):
    with open(directory + agent_ID + '.pkl', 'rb') as agent_file:
        agent_data = pickle.load(agent_file)
    return agent_data

def load_dict_agents_data(directory, skip_changing_users = True):
    result = {}
    all_agent_IDs = set([files[:-4] for files in os.listdir(directory) if files[0] != '.'])
    for ID in all_agent_IDs:
        if skip_changing_users and (ID in high_to_low_users or ID in low_to_high_users):
            continue
        agent_data = load_agent(directory, ID)
        if agent_data['user_type'] == 'regulier':
            result[ID] = agent_data
    return result

def get_dataframe_data(data_agents):
    stripped_dict = {}
    for agent in data_agents:
        stripped_dict[agent] = {}
        for key, val in data_agents[agent].items():
            if (isinstance(val, int) or isinstance(val, float) or isinstance(val, str)):
                stripped_dict[agent][key] = val
    return pandas.DataFrame.from_dict(stripped_dict, orient = 'index')

def load_agent_sessions(directory, data = pandas.DataFrame(), skip_changing_users = True):
    if len(data) == 0:
        path_to_file = 'data/sessions/ChargeSessions_general_filtered.pkl'
        with open(path_to_file, 'rb') as data_file:
            data = pickle.load(data_file)
    result = {}
    all_agent_IDs = set([files[:-4] for files in os.listdir(directory) if files[0] != '.'])
    for i, ID in enumerate(all_agent_IDs):
        if (i % 200 == 0):
            print("Loaded sessions for %d of %d agents" %(i, len(all_agent_IDs)))
        if skip_changing_users and (ID in high_to_low_users or ID in low_to_high_users):
            continue
        df = data.loc[data['ID'] == ID]
        df = df.sort_values(by = 'start_connection', inplace = False)
        result[ID] = df
    return result

def update_general_data():
    path_to_file = 'data/sessions/ChargeSessions_general.pkl'
    with open(path_to_file, 'rb') as data_file:
        data = pickle.load(data_file)
    df['connection_duration'] = df.apply(lambda row: row.end_connection - row.start_connection, axis = 1)
    df = df[df.connection_duration > min_duration_session] 
    path_to_file = 'data/sessions/ChargeSessions_general_filtered.pkl'
    with open(path_to_file, 'wb') as data_file:
            pickle.dump(df, data_file)

def update_agent_data(agent_dir, agent_ID, data_key, data, in_place = False, agent_data = None):
    ''' Updates the given agent with the given data in the database. The key data_key is added to the agent dictionary,
        and the data is added as value. This agent is then again saved in the same spot. 
    '''
    if agent_data == None:
        agent_data = load_agent(agent_dir, agent_ID)
    if not in_place:
        agent_data[data_key] = data
    save_agent(agent_dir, agent_data, agent_ID)

# %%
high_to_low_users = ['5D763B2DCBFD274859F43EE1456A1DD0B68F72A82E0A8564372C4BD46B95DAC8',
                    '8DD214E9F9611E7D01E662E940AC973BCC34CF45C3D43D3306DFD3F9AEB5075C',
                    '9A79FD1E5649B3FA3978C6B7E682571ED5570F5D1A35CDE4E80C6F30DFCFAF2B',
                    '09CAA3715AE1BC35FC152487BBD693275E97DE039207824D1063E5A7A0E2DD6E',
                    '144984E1475253AC45D743910C4CF344A2D315EA12ACD21AB58971105DEAF522',
                    'B8256507B35A603D43CF7437CCC5712F33F1F54B82EB416FEA942725AAD3831C',
                    'F32DBA25D91138963F85144783F71A16E4C2CF7D1523F0644A6404B4C2F227C4',
                    'F9541CDC30F3E36CEE3EE6954D0AC7D7925C5539D5E751E79AD13734E455ADBC']
low_to_high_users = ['6D47DA110FAA422E77B8DA82975F644315AC05C3D0E38B12A80816793452D857',
                    '8C45CDFC57F283C9BFB268CBD39725923FF8D22BCDF75E3E4FD054B079872459',
                    '9C510710140B57F6EB58CC760CCAE70064D161D0B993741CC479FAF65175B2CB',
                    '9D2D9AD61D9BCBF8A3CBBBEE6A031A7152EF2C28235E54CC5E1A478CC9BC9F73',
                    '17AFFF335DB8BF72259DD11C23D375ECA607613B2D9E1379AFF0922888A8EE90',
                    '53DDDDFF98D9CB22915B054A55F663BFDE941FFD8039A03248E559945C096031',
                    '80E9884E3E4B152B66E2B3A2861FE89BE1D48A346C16EF8739F9714F4BD6AEBB',
                    '606BD9C4F45EF4BD2710D2C4B178BF7356D2D9437BDF53B5593AB87F35A061B1',
                    '17897EE886276B2EA379234AC9112C0816C0C917977A8DB4E3282A3C9BE7D018',
                    '918130F5F1FC762D62308F082000F698F77C6CDBD34F9F4915835D484663A509',
                    'EDA3B229C2661C6E479A565173F553DB7A10275D5360E542DA626F96832C12C6',
                    'F346C8B51850F3D811CCDE0EC612153028C9F69E9B79C1FA9E4F5FA75F470AA9',
                    'FDC8791D2EE934F8A1DD22816E149DD2E37E185C985C772D38D44FE74AA207DE',
                    'F20D73D834CB2523C7E8E55643E2A7E6467DA5D4B4EBCA3547BC9FE49009E731']
wth_are_u_doing_users = ['7DA773D56D9BABA6B82139F286FA593EB0685317075EE743F05A3DDE1A1A552A',
                      '62ABF94F3B61963B34B78EA7F062DE8681015F17730270CCAA8F6BD61828889F',
                      '70E685BA7C2BC723DA307881476A3E5FC3AD1FCABDDFBF3A5BBA69E8BBB53B94']

# %%
% time data_agents = load_dict_agents_data('data/agent_database/all_non_changing_agents/')
data_agents_df = get_dataframe_data(data_agents)
# Out:
# CPU times: user 51.5 s, sys: 1.57 s, total: 53.1 s
# Wall time: 1min 5s

# %%
path_to_file = 'data/sessions/ChargeSessions_general_filtered.pkl'
with open(path_to_file, 'rb') as data_file:
    general_data = pickle.load(data_file)

# %%
with open('data/sessions/ChargeSessions_general_expanded_per_agent.pkl', 'rb') as df:
    sessions_data_expanded = pickle.load(df)
    
dfs_phev = []
dfs_low_fev = []
dfs_high_fev = []

for i, a in enumerate(sessions_data_expanded):
    if a not in data_agents:
        continue
    if data_agents[a]['battery_category'] == 'phev':
        dfs_phev.append(sessions_data_expanded[a])
    elif data_agents[a]['battery_category'] == 'fev_low':
        dfs_low_fev.append(sessions_data_expanded[a])
    elif data_agents[a]['battery_category'] == 'fev_high':
        dfs_high_fev.append(sessions_data_expanded[a])


phev_sessions = pandas.concat(dfs_phev)
low_fev_sessions = pandas.concat(dfs_low_fev)
high_fev_sessions = pandas.concat(dfs_high_fev)

phev_sessions['car_type']  = ['phev'] * len(phev_sessions)
low_fev_sessions['car_type']  = ['low_fev'] * len(low_fev_sessions)
high_fev_sessions['car_type']  = ['high_fev'] * len(high_fev_sessions)

all_sessions = pandas.concat([phev_sessions, low_fev_sessions, high_fev_sessions])

# %%
temp_agent_sessions = {}
prev = datetime.datetime.now()
for i, a in enumerate(data_agents):
    if i % 100 == 0:
        print("%d of %d, took: %s" %(i, len(data_agents), datetime.datetime.now() - prev))
        prev = datetime.datetime.now()
    df = all_sessions.loc[all_sessions.ID == a]
    df['previous_location_key'] = df.location_key.shift(1)
    df = df[df.previous_location_key != 'NaT']
    temp_agent_sessions[a] = df
# Out:
# 0 of 2242, took: 0:00:00.000726
# /usr/local/lib/python3.4/dist-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 100 of 2242, took: 0:01:55.249061
# 200 of 2242, took: 0:01:46.285261
# 300 of 2242, took: 0:01:54.933410
# 400 of 2242, took: 0:01:53.219279
# 500 of 2242, took: 0:01:51.797713
# 600 of 2242, took: 0:01:50.956315
# 700 of 2242, took: 0:01:53.129710
# 800 of 2242, took: 0:01:55.880877
# 900 of 2242, took: 0:01:54.239900
# 1000 of 2242, took: 0:02:01.938526
# 1100 of 2242, took: 0:02:00.558754
# 1200 of 2242, took: 0:02:01.527416
# 1300 of 2242, took: 0:02:03.597171
# 1400 of 2242, took: 0:01:57.408693
# 1500 of 2242, took: 0:01:50.927497
# 1600 of 2242, took: 0:01:53.930737
# 1700 of 2242, took: 0:01:59.048626
# 1800 of 2242, took: 0:02:00.222292
# 1900 of 2242, took: 0:02:01.995533
# 2000 of 2242, took: 0:02:00.186659
# 2100 of 2242, took: 0:01:57.449641
# 2200 of 2242, took: 0:01:52.052425

# %%
agent = list(temp_agent_sessions.keys())[0]
temp_agent_sessions[agent].columns
# len(temp_agent_sessions[agent])
# len(temp_agent_sessions[agent].loc[temp_agent_sessions[agent]['disconnection_duration_days'] < 1.0])
# Out:
# Index(['location_key', 'ID', 'start_connection', 'end_connection',
#        'connection_time_hours', 'kWh', 'city', 'region_abbreviation',
#        'provider', 'address', 'postal_code', 'district', 'subdistrict',
#        'latitude', 'longitude', 'amount_of_sockets', 'parking_zone',
#        'connection_duration', 'shifted_end_connection',
#        'disconnection_duration', 'disconnection_duration_days',
#        'connection_duration_days', 'weekday', 'kwh_grouped', 'car_type',
#        'previous_location_key'],
#       dtype='object')

# %%
total_nr_sessions = 0
total_nr_at_same = 0 
fracs = []
for a in temp_agent_sessions:
    short_sessions = temp_agent_sessions[a].loc[temp_agent_sessions[a]['disconnection_duration'] < pandas.to_timedelta('60min')]
    short_sessions = short_sessions.loc[short_sessions['disconnection_duration'] > pandas.to_timedelta('55min')]
    nr_short_sessions = len(short_sessions)
    if nr_short_sessions == 0:
        continue
    nr_at_same = len(short_sessions.loc[short_sessions['previous_location_key'] == short_sessions['location_key']])
    total_nr_sessions += nr_short_sessions
    total_nr_at_same += nr_at_same
    fracs.append(nr_at_same / (nr_short_sessions))

# %%
print(total_nr_sessions, total_nr_at_same, total_nr_at_same / total_nr_sessions)
# Out:
# 3883 2466 0.6350759721864537

# %%
print(numpy.mean(fracs), numpy.std(fracs))
# Out:
# 0.658719518051 0.40528841121

# %%
def get_connection_range(session):
    ''' This method generates the range of a charging session with the step
        size given in the bin_size_dist variable.

    Args:
        session (Series): The pandas Series from which to get the start and
            end times of the range.

    Returns:
        (DatetimeIndex): Containing Timestamps of the times between the
            start of the session and the end of the session with an
            interval between those times of the bin size of the simulation.
    '''

    range_session = pandas.date_range(session['start_connection'], session['end_connection'], freq = '20min')
    return (time for time in range_session)

def get_activity_patterns_centers(agent_sessions, centers_css):
    ''' This method calculates the activity patterns for each center of
        an agent.

    Args:
        agent_sessions (DataFrame): The sessions of the agent.
        centers_css (Dict[Tuple[float, float], Dict[str, Any]]): Centers
            (lon, lat) as keys and each center being a dictionary with the
            keys 'habit' and 'distance'. The value of the habit key is a set
            of charging stations (location keys), while the value of the
            distance key is a dictionary with the charging stations
            (location keys) as keys and their distance to the center (in
            meters) as value.

    Returns:
        activity_patterns (Dict[Tuple[float, float], List[float]]): A
            dictionary of activity patterns with the centers as keys.
            The activity patterns are lists of probabilities per bin with the
            probabilities indicating the chance of being connected to the
            center in the time interval of the bin.
    '''

    dists = {}
    if len(agent_sessions) > 0:
        for center in centers_css.keys():
            cluster_dataframes = [agent_sessions.loc[
                agent_sessions['location_key'] == cs] for cs in centers_css[center]['habit']]
            cluster_sessions = pandas.concat(cluster_dataframes)
            dists[center] = self.get_activity_pattern(cluster_sessions)
        return dists

    return {center: get_activity_pattern(pandas.DataFrame({}))
        for center in centers_css.keys()}

def get_activity_pattern(sessions):
    ''' This method calculates the activity pattern using the given sessions.

    Args:
        sessions (DataFrame): The sessions that will be used to
            create the activity pattern.

    Returns:
        (List[float]): The activity pattern being a list of probabilities
            per bin with the probabilities indicating the chance of being
            connected to the in the time interval of the bin.
    '''
    offset = pandas.to_datetime('01-01-2000', format='%d-%m-%Y')
    times_day = pandas.date_range(offset, offset + pandas.to_timedelta('23:59:59'), freq = '20min')

    if len(sessions) == 0:
        df = pandas.DataFrame({'times': times_day})
        df['0'] = pandas.Series([0] * len(times_day))
        df.set_index('times', drop = True, inplace = True)
        return [0] * len(times_day)

    sessions.all_dates = sessions.apply(lambda row: get_connection_range(row), axis = 1)
    list_all_dates = [list(dates) for dates in sessions.all_dates]
    times = []
    for dates in list_all_dates:
        for date in dates:
            times.append(date.replace(year = offset.year, month = offset.month, day = offset.day))
    df = pandas.DataFrame({'times': times})
    df.set_index('times', drop = False, inplace = True)
    df = df.groupby(pandas.TimeGrouper(freq = '20min')).count()

    if (len(df) < datetime.timedelta(days = 1) / datetime.timedelta(minutes = 20)):
        missing_indices = [time for time in times_day
            if time not in list(df.times.index)]
        missing_series = pandas.Series([0] * len(missing_indices),
            index = missing_indices)
        return df.times.append(missing_series).sort_index()
    else:
        return df.times
